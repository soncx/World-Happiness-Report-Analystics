# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# # **Load Dataset**

# %%
df2015 = pd.read_csv('/content/drive/MyDrive/Learn DA/Project/World Happiness Report/Data/2015.csv')
df2016 = pd.read_csv('/content/drive/MyDrive/Learn DA/Project/World Happiness Report/Data/2016.csv')
df2017 = pd.read_csv('/content/drive/MyDrive/Learn DA/Project/World Happiness Report/Data/2017.csv')
df2018 = pd.read_csv('/content/drive/MyDrive/Learn DA/Project/World Happiness Report/Data/2018.csv')
df2019 = pd.read_csv('/content/drive/MyDrive/Learn DA/Project/World Happiness Report/Data/2019.csv')
df2020 = pd.read_csv('/content/drive/MyDrive/Learn DA/Project/World Happiness Report/Data/2020.csv')
df2021 = pd.read_csv('/content/drive/MyDrive/Learn DA/Project/World Happiness Report/Data/2021.csv')
df2022 = pd.read_csv('/content/drive/MyDrive/Learn DA/Project/World Happiness Report/Data/2022.csv')

# %%
df2015.shape, df2016.shape, df2017.shape, df2018.shape, df2019.shape, df2020.shape, df2021.shape, df2022.shape
# Out:
# ((158, 12),
#  (157, 13),
#  (155, 12),
#  (156, 9),
#  (156, 9),
#  (153, 20),
#  (149, 20),
#  (147, 12))

# %%
# Add "Year" columns
years = ['2015','2016','2017','2018','2019','2020','2021','2022']
dataframes = [df2015, df2016, df2017, df2018, df2019, df2020, df2021, df2022]
for i in range(0,8):
  dataframes[i]['Year'] = years[i]

# %%
df2015.columns.to_list()
# Out:
# ['Country',
#  'Region',
#  'Happiness Rank',
#  'Happiness Score',
#  'Standard Error',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Trust (Government Corruption)',
#  'Generosity',
#  'Dystopia Residual',
#  'Year']

# %%
# Define common column names
common_cols = ['Country','Region','Happiness Rank','Happiness Score','Economy (GDP per Capita)','Family (Social Support)',
               'Health (Life Expectancy)','Freedom','Trust (Government Corruption)','Generosity','Year']

# %% [markdown]
# # **2015**

# %%
df2015.columns.to_list()
# Out:
# ['Country',
#  'Region',
#  'Happiness Rank',
#  'Happiness Score',
#  'Standard Error',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Trust (Government Corruption)',
#  'Generosity',
#  'Dystopia Residual',
#  'Year']

# %%
df2015 = df2015.rename(columns={'Family':'Family (Social Support)'})

# %%
df2015.head(3)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
#
#    Standard Error  Economy (GDP per Capita)  Family (Social Support)  \
# 0         0.03411                   1.39651                  1.34951
# 1         0.04884                   1.30232                  1.40223
# 2         0.03328                   1.32548                  1.36058
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
#
#    Generosity  Dystopia Residual  Year
# 0     0.29678            2.51738  2015
# 1     0.43630            2.70201  2015
# ...

# %% [markdown]
# # **2016**

# %%
df2016.columns.to_list()
# Out:
# ['Country',
#  'Region',
#  'Happiness Rank',
#  'Happiness Score',
#  'Lower Confidence Interval',
#  'Upper Confidence Interval',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Trust (Government Corruption)',
#  'Generosity',
#  'Dystopia Residual',
#  'Year']

# %%
df2016 = df2016.rename(columns={'Family':'Family (Social Support)'})

# %%
df2016.head(2)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                   1.44178                  1.16374
# 1                   1.52733                  1.14524
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.79504  0.57941                        0.44453
# 1                   0.86303  0.58557                        0.41203
#
#    Generosity  Dystopia Residual  Year
# 0     0.36171            2.73939  2016
# 1     0.28083            2.69463  2016

# %% [markdown]
# # **2017**

# %%
df2017.columns.to_list()
# Out:
# ['Country',
#  'Happiness.Rank',
#  'Happiness.Score',
#  'Whisker.high',
#  'Whisker.low',
#  'Economy..GDP.per.Capita.',
#  'Family',
#  'Health..Life.Expectancy.',
#  'Freedom',
#  'Generosity',
#  'Trust..Government.Corruption.',
#  'Dystopia.Residual',
#  'Year']

# %%
df2017 = df2017.rename(columns={'Happiness.Rank':'Happiness Rank','Happiness.Score':'Happiness Score',
                                 'Economy..GDP.per.Capita.':'Economy (GDP per Capita)','Family':'Family (Social Support)',
                                 'Health..Life.Expectancy.':'Health (Life Expectancy)',
                                 'Trust..Government.Corruption.':'Trust (Government Corruption)'})

# %%
# df2017 missing of "Region", so we merge(left-join) with df2015 to get Region by Country
df2017 = df2017.merge(df2015[['Country','Region']], on='Country', how='left')
df2017['Region'] = df2017['Region'].fillna('-')

# %%
df2017.sample(2)
# Out:
#       Country  Happiness Rank  Happiness Score  Whisker.high  Whisker.low  \
# 47      Italy              48            5.964      6.042737     5.885264
# 128  Cambodia             129            4.168      4.278518     4.057483
#
#      Economy (GDP per Capita)  Family (Social Support)  \
# 47                   1.395067                 1.444923
# 128                  0.601765                 1.006238
#
#      Health (Life Expectancy)   Freedom  Generosity  \
# 47                   0.853144  0.256451    0.172790
# 128                  0.429783  0.633376    0.385923
#
#      Trust (Government Corruption)  Dystopia.Residual  Year             Region
# 47                        0.028028           1.813312  2017     Western Europe
# 128                       0.068106           1.042941  2017  Southeastern Asia

# %%
df2017['Region'].value_counts()
# Out:
# Sub-Saharan Africa                 36
# Central and Eastern Europe         29
# Western Europe                     21
# Latin America and Caribbean        21
# Middle East and Northern Africa    19
# Southeastern Asia                   8
# Southern Asia                       7
# -                                   6
# Eastern Asia                        4
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %% [markdown]
# # **2018**

# %%
df2018.columns.to_list()
# Out:
# ['Overall rank',
#  'Country or region',
#  'Score',
#  'GDP per capita',
#  'Social support',
#  'Healthy life expectancy',
#  'Freedom to make life choices',
#  'Generosity',
#  'Perceptions of corruption',
#  'Year']

# %%
df2018.sample(2)
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 153           154       South Sudan  3.254           0.337           0.608
# 144           145       Afghanistan  3.632           0.332           0.537
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 153                    0.177                         0.112       0.224
# 144                    0.255                         0.085       0.191
#
#      Perceptions of corruption  Year
# 153                      0.106  2018
# 144                      0.036  2018

# %%
df2018 = df2018.rename(columns={'Overall rank':'Happiness Rank','Country or region':'Country',
                                'Score':'Happiness Score','GDP per capita':'Economy (GDP per Capita)',
                                'Social support':'Family (Social Support)','Healthy life expectancy':'Health (Life Expectancy)',
                                'Freedom to make life choices':'Freedom','Perceptions of corruption':'Trust (Government Corruption)'})

# %%
df2018.sample(2)
# Out:
#     Happiness Rank   Country  Happiness Score  Economy (GDP per Capita)  \
# 34              35  Malaysia            6.322                     1.161
# 90              91   Nigeria            5.155                     0.689
#
#     Family (Social Support)  Health (Life Expectancy)  Freedom  Generosity  \
# 34                    1.258                     0.669    0.356       0.311
# 90                    1.172                     0.048    0.462       0.201
#
#     Trust (Government Corruption)  Year
# 34                          0.059  2018
# 90                          0.032  2018

# %%
# df2018 missing of "Region", so we merge(left-join) with df2015 to get Region by Country
df2018 = df2018.merge(df2015[['Country','Region']], on='Country', how='left')
df2018['Region'] = df2018['Region'].fillna('-')

# %%
df2018.tail(2)
# Out:
#      Happiness Rank                   Country  Happiness Score  \
# 154             155  Central African Republic            3.083
# 155             156                   Burundi            2.905
#
#      Economy (GDP per Capita)  Family (Social Support)  \
# 154                     0.024                    0.000
# 155                     0.091                    0.627
#
#      Health (Life Expectancy)  Freedom  Generosity  \
# 154                     0.010    0.305       0.218
# 155                     0.145    0.065       0.149
#
#      Trust (Government Corruption)  Year              Region
# 154                          0.038  2018  Sub-Saharan Africa
# 155                          0.076  2018  Sub-Saharan Africa

# %%
df2018['Region'].value_counts()
# Out:
# Sub-Saharan Africa                 36
# Central and Eastern Europe         29
# Western Europe                     20
# Latin America and Caribbean        20
# Middle East and Northern Africa    19
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# -                                   6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %% [markdown]
# # **2019**

# %%
df2019.columns.to_list()
# Out:
# ['Overall rank',
#  'Country or region',
#  'Score',
#  'GDP per capita',
#  'Social support',
#  'Healthy life expectancy',
#  'Freedom to make life choices',
#  'Generosity',
#  'Perceptions of corruption',
#  'Year']

# %%
df2019.head(1)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769            1.34           1.587
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
#
#    Perceptions of corruption  Year
# 0                      0.393  2019

# %%
df2019 = df2019.rename(columns={'Overall rank':'Happiness Rank','Country or region':'Country',
                                'Score':'Happiness Score','GDP per capita':'Economy (GDP per Capita)',
                                'Social support':'Family (Social Support)','Healthy life expectancy':'Health (Life Expectancy)',
                                'Freedom to make life choices':'Freedom','Perceptions of corruption':'Trust (Government Corruption)'})

# %%
df2019.head(2)
# Out:
#    Happiness Rank  Country  Happiness Score  Economy (GDP per Capita)  \
# 0               1  Finland            7.769                     1.340
# 1               2  Denmark            7.600                     1.383
#
#    Family (Social Support)  Health (Life Expectancy)  Freedom  Generosity  \
# 0                    1.587                     0.986    0.596       0.153
# 1                    1.573                     0.996    0.592       0.252
#
#    Trust (Government Corruption)  Year
# 0                          0.393  2019
# 1                          0.410  2019

# %%
# df2019 missing of "Region", so we merge(left-join) with df2015 to get Region by Country
df2019 = df2019.merge(df2015[['Country','Region']], on='Country', how='left')
df2019['Region'] = df2019['Region'].fillna('-')

# %%
df2019['Region'].value_counts()
# Out:
# Sub-Saharan Africa                 36
# Central and Eastern Europe         28
# Western Europe                     20
# Latin America and Caribbean        20
# Middle East and Northern Africa    19
# Southeastern Asia                   9
# -                                   7
# Southern Asia                       7
# Eastern Asia                        6
# Australia and New Zealand           2
# North America                       2
# Name: Region, dtype: int64

# %% [markdown]
# # **2020**

# %%
df2020.columns.to_list()
# Out:
# ['Country name',
#  'Regional indicator',
#  'Ladder score',
#  'Standard error of ladder score',
#  'upperwhisker',
#  'lowerwhisker',
#  'Logged GDP per capita',
#  'Social support',
#  'Healthy life expectancy',
#  'Freedom to make life choices',
#  'Generosity',
#  'Perceptions of corruption',
#  'Ladder score in Dystopia',
#  'Explained by: Log GDP per capita',
#  'Explained by: Social support',
#  'Explained by: Healthy life expectancy',
#  'Explained by: Freedom to make life choices',
#  'Explained by: Generosity',
#  'Explained by: Perceptions of corruption',
#  'Dystopia + residual',
#  'Year']

# %%
df2020.head(1)
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.639267         0.95433                71.900825
#
#    Freedom to make life choices  ...  Perceptions of corruption  \
# 0                      0.949172  ...                   0.195445
#
#    Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                  1.972317                           1.28519
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                      1.499526                               0.961271
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                    0.662317                   0.15967
#
# ...

# %%
df2020 = df2020.rename(columns={'Country name':'Country','Regional indicator':'Region',
                                'Ladder score':'Happiness Score',
                               'Explained by: Log GDP per capita':'Economy (GDP per Capita)',
                               'Explained by: Social support':'Family (Social Support)',
                               'Explained by: Healthy life expectancy':'Health (Life Expectancy)',
                               'Explained by: Freedom to make life choices':'Freedom',
                               'Explained by: Generosity':'Generosity',
                               'Explained by: Perceptions of corruption':'Trust (Government Corruption)'})

# %%
# df2020 missing of "Happiness Rank", so add Rank by index 
df2020['Happiness Rank'] = [i for i in range(1, (len(df2020.index)+1))]

# %%
df2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Country                         153 non-null    object
#  1   Region                          153 non-null    object
#  2   Happiness Score                 153 non-null    float64
#  3   Standard error of ladder score  153 non-null    float64
#  4   upperwhisker                    153 non-null    float64
#  5   lowerwhisker                    153 non-null    float64
#  6   Logged GDP per capita           153 non-null    float64
#  7   Social support                  153 non-null    float64
#  8   Healthy life expectancy         153 non-null    float64
#  9   Freedom to make life choices    153 non-null    float64
#  10  Generosity                      153 non-null    float64
#  11  Perceptions of corruption       153 non-null    float64
# ...

# %%
# Control wether there are any duplicate cols
df2020 = df2020.loc[:,~df2020.columns.duplicated(keep='last')]

# %%
pd.set_option("display.max_columns",22)
df2020.head(2)
# Out:
#    Country          Region  Happiness Score  Standard error of ladder score  \
# 0  Finland  Western Europe           7.8087                        0.031156
# 1  Denmark  Western Europe           7.6456                        0.033492
#
#    upperwhisker  lowerwhisker  Logged GDP per capita  Social support  \
# 0      7.869766      7.747634              10.639267        0.954330
# 1      7.711245      7.579955              10.774001        0.955991
#
#    Healthy life expectancy  Freedom to make life choices  \
# 0                71.900825                      0.949172
# 1                72.402504                      0.951444
#
#    Perceptions of corruption  Ladder score in Dystopia  \
# 0                   0.195445                  1.972317
# 1                   0.168489                  1.972317
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                  1.285190                 1.499526
# 1                  1.326949                 1.503449
#
# ...

# %% [markdown]
# # **2021**

# %%
df2021.columns.to_list()
# Out:
# ['Country name',
#  'Regional indicator',
#  'Ladder score',
#  'Standard error of ladder score',
#  'upperwhisker',
#  'lowerwhisker',
#  'Logged GDP per capita',
#  'Social support',
#  'Healthy life expectancy',
#  'Freedom to make life choices',
#  'Generosity',
#  'Perceptions of corruption',
#  'Ladder score in Dystopia',
#  'Explained by: Log GDP per capita',
#  'Explained by: Social support',
#  'Explained by: Healthy life expectancy',
#  'Explained by: Freedom to make life choices',
#  'Explained by: Generosity',
#  'Explained by: Perceptions of corruption',
#  'Dystopia + residual',
#  'Year']

# %%
common_cols
# Out:
# ['Country',
#  'Region',
#  'Happiness Rank',
#  'Happiness Score',
#  'Economy (GDP per Capita)',
#  'Family (Social Support)',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Trust (Government Corruption)',
#  'Generosity',
#  'Year']

# %%
df2021.head(1)
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904          7.78
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.949      -0.098                      0.186
#
#    Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                      2.43                             1.446
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.106                                  0.741
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                       0.691                     0.124
#
# ...

# %%
df2021 = df2021.rename(columns={'Country name':'Country','Regional indicator':'Region','Ladder score':'Happiness Score',
                                'Explained by: Log GDP per capita':'Economy (GDP per Capita)',
                                'Explained by: Social support':'Family (Social Support)',
                                'Explained by: Healthy life expectancy':'Health (Life Expectancy)',
                                'Explained by: Freedom to make life choices':'Freedom',
                                'Explained by: Generosity':'Generosity','Explained by: Perceptions of corruption':'Trust (Government Corruption)'})

# %%
# Control wether there are any duplicate cols
df2021 = df2021.loc[:,~df2021.columns.duplicated(keep='last')]

# %%
df2021['Happiness Rank'] = [i for i in range(1,len(df2021.index)+1)]

# %%
df2021.head(2)
# Out:
#    Country          Region  Happiness Score  Standard error of ladder score  \
# 0  Finland  Western Europe            7.842                           0.032
# 1  Denmark  Western Europe            7.620                           0.035
#
#    upperwhisker  lowerwhisker  Logged GDP per capita  Social support  \
# 0         7.904         7.780                 10.775           0.954
# 1         7.687         7.552                 10.933           0.954
#
#    Healthy life expectancy  Freedom to make life choices  \
# 0                     72.0                         0.949
# 1                     72.7                         0.946
#
#    Perceptions of corruption  Ladder score in Dystopia  \
# 0                      0.186                      2.43
# 1                      0.179                      2.43
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                     1.446                    1.106
# 1                     1.502                    1.108
#
# ...

# %% [markdown]
# # **2022**

# %%
df2022.columns.to_list()
# Out:
# ['RANK',
#  'Country',
#  'Happiness score',
#  'Whisker-high',
#  'Whisker-low',
#  'Dystopia (1.83) + residual',
#  'Explained by: GDP per capita',
#  'Explained by: Social support',
#  'Explained by: Healthy life expectancy',
#  'Explained by: Freedom to make life choices',
#  'Explained by: Generosity',
#  'Explained by: Perceptions of corruption',
#  'Year']

# %%
df2022 = df2022.rename(columns={'RANK':'Happiness Rank','Happiness score':'Happiness Score',
                       'Explained by: GDP per capita':'Economy (GDP per Capita)',
                       'Explained by: Social support':'Family (Social Support)',
                       'Explained by: Healthy life expectancy':'Health (Life Expectancy)',
                       'Explained by: Freedom to make life choices':'Freedom',
                       'Explained by: Generosity':'Generosity',
                       'Explained by: Perceptions of corruption':'Trust (Government Corruption)'})

# %%
df2022 = df2022.merge(df2015[['Country','Region']], on='Country', how='left')
df2022['Region'] = df2022['Region'].fillna('-')

# %%
df2022['Region'].value_counts()
# Out:
# -                                  28
# Central and Eastern Europe         24
# Sub-Saharan Africa                 22
# Western Europe                     19
# Latin America and Caribbean        18
# Middle East and Northern Africa    13
# Southeastern Asia                   9
# Southern Asia                       6
# Eastern Asia                        4
# Australia and New Zealand           2
# North America                       2
# Name: Region, dtype: int64

# %%
df2022.head(2)
# Out:
#    Happiness Rank  Country Happiness Score Whisker-high Whisker-low  \
# 0               1  Finland           7,821        7,886       7,756
# 1               2  Denmark           7,636        7,710       7,563
#
#   Dystopia (1.83) + residual Economy (GDP per Capita) Family (Social Support)  \
# 0                      2,518                    1,892                   1,258
# 1                      2,226                    1,953                   1,243
#
#   Health (Life Expectancy) Freedom Generosity Trust (Government Corruption)  \
# 0                    0,775   0,736      0,109                         0,534
# 1                    0,777   0,719      0,188                         0,532
#
#    Year          Region
# 0  2022  Western Europe
# 1  2022  Western Europe

# %% [markdown]
# # **Merge Dataframes**

# %%
common_cols
# Out:
# ['Country',
#  'Region',
#  'Happiness Rank',
#  'Happiness Score',
#  'Economy (GDP per Capita)',
#  'Family (Social Support)',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Trust (Government Corruption)',
#  'Generosity',
#  'Year']

# %%
dfs = [df2015[common_cols], df2016[common_cols], df2017[common_cols], df2018[common_cols], 
       df2019[common_cols], df2020[common_cols], df2021[common_cols], df2022[common_cols]]

# %%
df_merged = pd.DataFrame(columns=common_cols)

# %%
df_merged = df_merged.append(dfs)

# %%
df_merged.sample(5)
# Out:
#        Country                           Region Happiness Rank  \
# 103     Turkey     Middle East and North Africa            104
# 147      Haiti      Latin America and Caribbean            148
# 90     Lebanon  Middle East and Northern Africa             91
# 133    Comoros               Sub-Saharan Africa            134
# 40   Lithuania       Central and Eastern Europe             41
#
#     Happiness Score Economy (GDP per Capita) Family (Social Support)  \
# 103           4.948                     1.26                   0.809
# 147           3.582                    0.315                   0.714
# 90            5.197                    0.987                   1.224
# 133          4.2886                 0.415621                0.723233
# 40           6.2155                  1.19356                1.432866
#
#     Health (Life Expectancy)   Freedom Trust (Government Corruption)  \
# 103                     0.59     0.236                         0.104
# ...

# %%
df_merged.shape
# Out:
# (1231, 11)

# %%
df_merged.dropna(axis='rows', inplace=True)

# %%
df_merged.shape
# Out:
# (1229, 11)

# %%
df = df_merged.to_csv('/content/drive/MyDrive/Learn DA/Project/World Happiness Report/world_happiness_report_cleaned.csv')
